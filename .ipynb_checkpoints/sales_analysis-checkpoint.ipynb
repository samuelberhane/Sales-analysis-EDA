# %% [markdown]
# # Exploratory Data Analysis
# ## Sales Analysis

# %% [markdown]
# #### Import python libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os
import calendar

# %% [markdown]
# #### Merge dataset into single file

# %%
dataframe = []
files = [file for file in os.listdir(os.path.join("./Sales_Data"))]
for file in files:
    df = pd.read_csv(os.path.join(f"./Sales_Data/{file}"))
    dataframe.append(df)

sales_data = pd.concat(dataframe)
sales_data.to_csv("sales_data.csv", index=False)

# %%
df = pd.read_csv("sales_data.csv")
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# ### 1. What was the best month for sales?

# %%
df.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186850 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB

# %%
df.describe()
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count     186305                186305           186305     186305
# unique    178438                    20               10         24
# top     Order ID  USB-C Charging Cable                1      11.95
# freq         355                 21903           168552      21903
#
#         Order Date  Purchase Address
# count       186305            186305
# unique      142396            140788
# top     Order Date  Purchase Address
# freq           355               355

# %% [markdown]
# #### Clean date(drop NaN values)

# %%
df = df.dropna(axis=0)
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# #### Add Month column to dataframe

# %%
df["Month"] = df["Order Date"].str[0:2]
# Out:
# C:\TEMP\ipykernel_3188\2629772142.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Month"] = df["Order Date"].str[0:2]

# %%
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address Month
# ...

# %% [markdown]
# #### Drop rows with Month column contain "Or"

# %%
df = df[df["Month"].str.contains("Or")==False]

# %%
df["Month"] = df["Month"].apply(int)
# Out:
# C:\TEMP\ipykernel_3188\1835201879.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Month"] = df["Month"].apply(int)

# %%
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address  Month
# ...

# %%
df["Month"].value_counts().sort_index().plot(kind="bar", title="Amount of sales per month")
# Out:
# <Axes: title={'center': 'Amount of sales per month'}>

# %% [markdown]
# #### Change numeric column of string to numeric values

# %%
df["Quantity Ordered"] = pd.to_numeric(df["Quantity Ordered"])
df["Price Each"] = pd.to_numeric(df["Price Each"])
# Out:
# C:\TEMP\ipykernel_3188\3296997963.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Quantity Ordered"] = pd.to_numeric(df["Quantity Ordered"])
# C:\TEMP\ipykernel_3188\3296997963.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Price Each"] = pd.to_numeric(df["Price Each"])

# %%
df["Total Sales"] = df["Quantity Ordered"] * df["Price Each"]
# Out:
# C:\TEMP\ipykernel_3188\3931643687.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Total Sales"] = df["Quantity Ordered"] * df["Price Each"]

# %%
df.insert(4, 'Total Sales', df.pop('Total Sales'))

# %%
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#         Total Sales      Order Date                         Purchase Address  \
# ...

# %%
sales_per_month = df.groupby(by=["Month"]).sum()
sales_per_month
# Out:
# C:\TEMP\ipykernel_3188\1776255226.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales_per_month = df.groupby(by=["Month"]).sum()
#        Quantity Ordered  Price Each  Total Sales
# Month
# 1                 10903  1811768.38   1822256.73
# 2                 13449  2188884.72   2202022.42
# 3                 17005  2791207.83   2807100.38
# 4                 20558  3367671.02   3390670.24
# 5                 18667  3135125.13   3152606.75
# 6                 15253  2562025.61   2577802.26
# 7                 16072  2632539.56   2647775.76
# 8                 13448  2230345.42   2244467.88
# 9                 13109  2084992.09   2097560.13
# 10                22703  3715554.83   3736726.88
# 11                19798  3180600.68   3199603.20
# ...

# %%
X = pd.Series(sales_per_month.index)
str_month = X.apply(lambda x: calendar.month_name[x][0:3])
Y = sales_per_month["Total Sales"]
plt.plot(str_month,Y)
plt.title("Total Sales For Each Month")
plt.ylabel("Total Sales (USD)")
plt.xlabel("Month of the year")
# Out:
# Text(0.5, 0, 'Month of the year')

# %% [markdown]
# ### 2.  In which city is the most profit generated?

# %% [markdown]
# #### Add city column

# %%
df["City"] = df["Purchase Address"].str.split(",").apply(lambda x: x[1])
# Out:
# C:\TEMP\ipykernel_3188\1167410387.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["City"] = df["Purchase Address"].str.split(",").apply(lambda x: x[1])

# %%
sales_per_city = df.groupby(by=["City"]).sum()
sales_per_city
# Out:
# C:\TEMP\ipykernel_3188\2726335162.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales_per_city = df.groupby(by=["City"]).sum()
#                 Quantity Ordered  Price Each  Total Sales   Month
# City
#  Atlanta                   16602  2779908.20   2795498.58  104794
#  Austin                    11153  1809873.61   1819581.75   69829
#  Boston                    22528  3637409.77   3661642.01  141112
#  Dallas                    16730  2752627.82   2767975.40  104620
#  Los Angeles               33289  5421435.23   5452570.80  208325
#  New York City             27932  4635370.83   4664317.43  175741
#  Portland                  14053  2307747.47   2320490.61   87765
#  San Francisco             50239  8211461.74   8262203.91  315520
# ...

# %%
X = sales_per_city.index
Y = sales_per_city["Total Sales"]
plt.bar(X,Y)
plt.xticks(rotation=90)
plt.title("Total Sales Per City")
plt.ylabel("Total Sales (USD)")
plt.xlabel("City")
# Out:
# Text(0.5, 0, 'City')
